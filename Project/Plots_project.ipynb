# %% [markdown]
# # Analisi comparativa di 4 algoritmi di ordinamento

# %% [markdown]
# Autori:      Grossi Mara (159901) - Toneatto Jessica (153425)

# %% [markdown]
# ## Gestione moduli e caricamento dati

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

n_data = pd.read_csv("Results_n.csv")  
n_data
# Out:
#         n  CountingSort     sd_CS  QuickSort         sd_QS  InsertionSort  \
# 0     100      0.000738  0.000097   0.000004  1.372370e-07       0.000003
# 1     107      0.000616  0.000067   0.000002  5.253640e-08       0.000002
# 2     114      0.000516  0.000029   0.000002  9.152270e-08       0.000002
# 3     123      0.000465  0.000027   0.000002  3.162000e-08       0.000002
# 4     132      0.000425  0.000018   0.000002  3.335210e-08       0.000002
# ..    ...           ...       ...        ...           ...            ...
# 95  75646      0.001123  0.000015   0.010059  1.239700e-04       2.570120
# 96  81112      0.001179  0.000009   0.010911  8.452050e-05       2.958110
# 97  86974      0.001236  0.000017   0.011851  2.124620e-04       3.407110
# 98  93259      0.001299  0.000014   0.012679  1.706520e-04       3.932160
# 99  99999      0.001364  0.000018   0.013801  1.970760e-04       4.511170
#
#            sd_IS  QuickSort3Ways       sd_QS3W
# ...

# %%
m_data = pd.read_csv("Results_m.csv")
m_data
# Out:
#           m  CountingSort         sd_CS  QuickSort     sd_QS  InsertionSort  \
# 0        10      0.000079  4.486760e-07   0.022935  0.000034       0.039759
# 1        11      0.000079  1.878260e-07   0.020900  0.000024       0.040406
# 2        12      0.000079  1.926930e-07   0.019253  0.000021       0.040848
# 3        14      0.000078  1.788970e-07   0.016567  0.000034       0.040994
# 4        15      0.000078  1.889900e-06   0.015503  0.000034       0.041405
# ..      ...           ...           ...        ...       ...            ...
# 95   628029      0.002554  1.355190e-05   0.001101  0.000021       0.044533
# 96   705480      0.002858  1.728390e-05   0.001099  0.000019       0.044677
# 97   792483      0.003201  1.879980e-05   0.001113  0.000028       0.044282
# 98   890215      0.003581  1.915310e-05   0.001107  0.000021       0.044345
# 99  1000000      0.004012  2.248310e-05   0.001105  0.000021       0.044388
#
#        sd_IS  QuickSort3Ways   sd_QS3W
# ...

# %% [markdown]
# ## Analisi per n variabile

# %% [markdown]
# ### Grafici individuali (scala lineare)

# %%
fig, axes = plt.subplots(2, 2, figsize = (13, 8))

fig.suptitle("Algoritmi individuali (scala lineare)")

axes[0][0].plot(n_data["n"], n_data["CountingSort"], color = "#e60049", label = "CountingSort")

axes[0][0].set_title("CountingSort")
axes[0][0].set_xlabel("size (n)")
axes[0][0].set_ylabel("time (ns)")

axes[0][1].plot(n_data["n"], n_data["QuickSort"], color = "#0bb4ff", label = "QuickSort")

axes[0][1].set_title("QuickSort")
axes[0][1].set_xlabel("size (n)")
axes[0][1].set_ylabel("time (ns)")

axes[1][0].plot(n_data["n"], n_data["InsertionSort"], color = "#87bc45", label = "InsertionSort")

axes[1][0].set_title("InsertionSort")
axes[1][0].set_xlabel("size (n)")
axes[1][0].set_ylabel("time (ns)")

axes[1][1].plot(n_data["n"], n_data["QuickSort3Ways"], color = "#edbf33", label = "QuickSort-3-Ways")

axes[1][1].set_title("QuickSort-3-Ways")
axes[1][1].set_xlabel("size (n)")
axes[1][1].set_ylabel("time (ns)")

handles, labels = axes[0][0].get_legend_handles_labels()

fig.tight_layout(rect = [0, 0.15, 1, 1])

plt.show()

# %% [markdown]
# ### Grafici individuali (scala logaritmica)

# %%
fig, axes = plt.subplots(2, 2, figsize = (13, 8))

fig.suptitle("Algoritmi individuali (scala logaritmica)")

axes[0][0].plot(n_data["n"], n_data["CountingSort"], color = "#e60049", label = "CountingSort")

axes[0][0].set_title("CountingSort")
axes[0][0].set_xlabel("size (n)")
axes[0][0].set_ylabel("time (ns)")
axes[0][0].set_xscale("log")
axes[0][0].set_yscale("log")

axes[0][1].plot(n_data["n"], n_data["QuickSort"], color = "#0bb4ff", label = "QuickSort")

axes[0][1].set_title("QuickSort")
axes[0][1].set_xlabel("size (n)")
axes[0][1].set_ylabel("time (ns)")
axes[0][1].set_xscale("log")
axes[0][1].set_yscale("log")

axes[1][0].plot(n_data["n"], n_data["InsertionSort"], color = "#87bc45", label = "InsertionSort")

axes[1][0].set_title("InsertionSort")
axes[1][0].set_xlabel("size (n)")
axes[1][0].set_ylabel("time (ns)")
axes[1][0].set_xscale("log")
axes[1][0].set_yscale("log")

axes[1][1].plot(n_data["n"], n_data["QuickSort3Ways"], color = "#edbf33", label = "QuickSort-3-Ways")

axes[1][1].set_title("QuickSort-3-Ways")
axes[1][1].set_xlabel("size (n)")
axes[1][1].set_ylabel("time (ns)")
axes[1][1].set_xscale("log")
axes[1][1].set_yscale("log")

handles, labels = axes[0][0].get_legend_handles_labels()

fig.tight_layout(rect = [0, 0.15, 1, 1])

plt.show()

# %% [markdown]
# ### Grafici comparativi

# %%
fig, axes = plt.subplots(1, 2, figsize = (13, 6))

fig.suptitle("Confronto algoritmi di ordinamento")

axes[0].plot(n_data["n"], n_data["CountingSort"], color = "#e60049", label = "CountingSort")
axes[0].plot(n_data["n"], n_data["QuickSort"], color = "#0bb4ff", label = "QuickSort")
axes[0].plot(n_data["n"], n_data["InsertionSort"], color = "#87bc45", label = "InsertionSort")
axes[0].plot(n_data["n"], n_data["QuickSort3Ways"], color = "#edbf33", label = "QuickSort-3-Ways")

axes[0].set_title("Scala lineare")

axes[0].set_xlabel("size (n)")
axes[0].set_ylabel("time (ns)")

axes[1].plot(n_data["n"], n_data["CountingSort"], color = "#e60049")
axes[1].plot(n_data["n"], n_data["QuickSort"], color = "#0bb4ff")
axes[1].plot(n_data["n"], n_data["InsertionSort"], color = "#87bc45")
axes[1].plot(n_data["n"], n_data["QuickSort3Ways"], color = "#edbf33")

axes[1].set_title("Scala logaritmica")

axes[1].set_xlabel("size (n) [log]")
axes[1].set_ylabel("time (ns) [log]")

axes[1].set_xscale("log")
axes[1].set_yscale("log")

handles, labels = axes[0].get_legend_handles_labels()

fig.tight_layout(rect = [0, 0.15, 1, 1])
fig.legend(handles, labels, loc = 'lower center', ncol = 2) 

plt.show()

# %% [markdown]
# ### Standard deviation

# %%
fig, axes = plt.subplots(2, 2, figsize = (13, 8))

fig.suptitle("Standard deviation - n variabile")

axes[0][0].fill_between(n_data["n"], n_data["CountingSort"] - n_data["sd_CS"], n_data["CountingSort"] + n_data["sd_CS"], color = "#e60049", alpha = 0.6, label = "CountingSort")

axes[0][0].set_title("CountingSort")
axes[0][0].set_xlabel("size (n)")
axes[0][0].set_ylabel("time (ns)")
axes[0][0].set_xscale("log")
axes[0][0].set_yscale("log")

axes[0][1].fill_between(n_data["n"], n_data["QuickSort"] - n_data["sd_QS"], n_data["QuickSort"] + n_data["sd_QS"], color = "#0bb4ff", alpha = 0.6, label = "QuickSort")

axes[0][1].set_title("QuickSort")
axes[0][1].set_xlabel("size (n)")
axes[0][1].set_ylabel("time (ns)")
axes[0][1].set_xscale("log")
axes[0][1].set_yscale("log")

axes[1][0].fill_between(n_data["n"], n_data["InsertionSort"] - n_data["sd_IS"], n_data["InsertionSort"] + n_data["sd_IS"], color = "#87bc45", alpha = 0.6, label = "InsertionSort")

axes[1][0].set_title("InsertionSort")
axes[1][0].set_xlabel("size (n)")
axes[1][0].set_ylabel("time (ns)")
axes[1][0].set_xscale("log")
axes[1][0].set_yscale("log")

axes[1][1].fill_between(n_data["n"], n_data["QuickSort3Ways"] - n_data["sd_QS3W"], n_data["QuickSort3Ways"] + n_data["sd_QS3W"], color = "#edbf33", alpha = 0.6, label = "QuickSort3Ways")

axes[1][1].set_title("QuickSort-3-Ways")
axes[1][1].set_xlabel("size (n)")
axes[1][1].set_ylabel("time (ns)")
axes[1][1].set_xscale("log")
axes[1][1].set_yscale("log")

handles, labels = axes[0][0].get_legend_handles_labels()

fig.tight_layout(rect = [0, 0.15, 1, 1])

plt.show()

# %% [markdown]
# ## Analisi per m variabile

# %% [markdown]
# ### Grafici individuali (scala lineare)

# %%
fig, axes = plt.subplots(2, 2, figsize = (13, 8))

fig.suptitle("Algoritmi individuali (scala lineare)")

axes[0][0].plot(m_data["m"], m_data["CountingSort"], color = "#e60049", label = "CountingSort")

axes[0][0].set_title("CountingSort")
axes[0][0].set_xlabel("range (m)")
axes[0][0].set_ylabel("time (ns)")

axes[0][1].plot(m_data["m"], m_data["QuickSort"], color = "#0bb4ff", label = "QuickSort")

axes[0][1].set_title("QuickSort")
axes[0][1].set_xlabel("range (m)")
axes[0][1].set_ylabel("time (ns)")

axes[1][0].plot(m_data["m"], m_data["InsertionSort"], color = "#87bc45", label = "InsertionSort")

axes[1][0].set_title("InsertionSort")
axes[1][0].set_xlabel("range (m)")
axes[1][0].set_ylabel("time (ns)")

axes[1][1].plot(m_data["m"], m_data["QuickSort3Ways"], color = "#edbf33", label = "QuickSort-3-Ways")

axes[1][1].set_title("QuickSort-3-Ways")
axes[1][1].set_xlabel("range (m)")
axes[1][1].set_ylabel("time (ns)")

handles, labels = axes[0][0].get_legend_handles_labels()

fig.tight_layout(rect = [0, 0.15, 1, 1])

plt.show()

# %% [markdown]
# ### Grafici individuali (scala logaritmica)

# %%
fig, axes = plt.subplots(2, 2, figsize = (13, 8))

fig.suptitle("Algoritmi individuali (scala logaritmica)")

axes[0][0].plot(m_data["m"], m_data["CountingSort"], color = "#e60049", label = "CountingSort")

axes[0][0].set_title("CountingSort")
axes[0][0].set_xlabel("range (m)")
axes[0][0].set_ylabel("time (ns)")
axes[0][0].set_xscale("log")
axes[0][0].set_yscale("log")

axes[0][1].plot(m_data["m"], m_data["QuickSort"], color = "#0bb4ff", label = "QuickSort")

axes[0][1].set_title("QuickSort")
axes[0][1].set_xlabel("range (m)")
axes[0][1].set_ylabel("time (ns)")
axes[0][1].set_xscale("log")
axes[0][1].set_yscale("log")

axes[1][0].plot(m_data["m"], m_data["InsertionSort"], color = "#87bc45", label = "InsertionSort")

axes[1][0].set_title("InsertionSort")
axes[1][0].set_xlabel("range (m)")
axes[1][0].set_ylabel("time (ns)")
axes[1][0].set_xscale("log")
axes[1][0].set_yscale("log")

axes[1][1].plot(m_data["m"], m_data["QuickSort3Ways"], color = "#edbf33", label = "QuickSort-3-Ways")

axes[1][1].set_title("QuickSort-3-Ways")
axes[1][1].set_xlabel("range (m)")
axes[1][1].set_ylabel("time (ns)")
axes[1][1].set_xscale("log")
axes[1][1].set_yscale("log")

handles, labels = axes[0][0].get_legend_handles_labels()

fig.tight_layout(rect = [0, 0.15, 1, 1])

plt.show()

# %% [markdown]
# ### Grafici comparativi

# %%
fig, axes = plt.subplots(1, 2, figsize = (13, 6))

fig.suptitle("Confronto algoritmi di ordinamento")

axes[0].plot(m_data["m"], m_data["CountingSort"], color = "#e60049", label = "CountingSort")
axes[0].plot(m_data["m"], m_data["QuickSort"], color = "#0bb4ff", label = "QuickSort")
axes[0].plot(m_data["m"], m_data["InsertionSort"], color = "#87bc45", label = "InsertionSort")
axes[0].plot(m_data["m"], m_data["QuickSort3Ways"], color = "#edbf33", label = "QuickSort-3-Ways")

axes[0].set_title("Scala lineare")

axes[0].set_xlabel("range (m)")
axes[0].set_ylabel("time (ns)")

axes[1].plot(m_data["m"], m_data["CountingSort"], color = "#e60049")
axes[1].plot(m_data["m"], m_data["QuickSort"], color = "#0bb4ff")
axes[1].plot(m_data["m"], m_data["InsertionSort"], color = "#87bc45")
axes[1].plot(m_data["m"], m_data["QuickSort3Ways"], color = "#edbf33")

axes[1].set_title("Scala logaritmica")

axes[1].set_xlabel("range (m) [log]")
axes[1].set_ylabel("time (ns) [log]")

axes[1].set_xscale("log")
axes[1].set_yscale("log")

handles, labels = axes[0].get_legend_handles_labels()

fig.tight_layout(rect = [0, 0.15, 1, 1])
fig.legend(handles, labels, loc = 'lower center', ncol = 2) 

plt.show()

# %% [markdown]
# ### Standard deviation

# %%
fig, axes = plt.subplots(2, 2, figsize = (13, 8))

fig.suptitle("Standard deviation - m variabile")

axes[0][0].fill_between(m_data["m"], m_data["CountingSort"] - m_data["sd_CS"], m_data["CountingSort"] + m_data["sd_CS"], color = "#e60049", alpha = 0.6, label = "CountingSort")

axes[0][0].set_title("CountingSort")
axes[0][0].set_xlabel("size (n)")
axes[0][0].set_ylabel("time (ns)")
axes[0][0].set_xscale("log")
axes[0][0].set_yscale("log")

axes[0][1].fill_between(m_data["m"], m_data["QuickSort"] - m_data["sd_QS"], m_data["QuickSort"] + m_data["sd_QS"], color = "#0bb4ff", alpha = 0.6, label = "QuickSort")

axes[0][1].set_title("QuickSort")
axes[0][1].set_xlabel("size (n)")
axes[0][1].set_ylabel("time (ns)")
axes[0][1].set_xscale("log")
axes[0][1].set_yscale("log")

axes[1][0].fill_between(m_data["m"], m_data["InsertionSort"] - m_data["sd_IS"], m_data["InsertionSort"] + m_data["sd_IS"], color = "#87bc45", alpha = 0.6, label = "InsertionSort")

axes[1][0].set_title("InsertionSort")
axes[1][0].set_xlabel("size (n)")
axes[1][0].set_ylabel("time (ns)")
axes[1][0].set_xscale("log")
axes[1][0].set_yscale("log")

axes[1][1].fill_between(m_data["m"], m_data["QuickSort3Ways"] - m_data["sd_QS3W"], m_data["QuickSort3Ways"] + m_data["sd_QS3W"], color = "#edbf33", alpha = 0.6, label = "QuickSort3Ways")

axes[1][1].set_title("QuickSort-3-Ways")
axes[1][1].set_xlabel("size (n)")
axes[1][1].set_ylabel("time (ns)")
axes[1][1].set_xscale("log")
axes[1][1].set_yscale("log")

handles, labels = axes[0][0].get_legend_handles_labels()

fig.tight_layout(rect = [0, 0.15, 1, 1])

plt.show()
